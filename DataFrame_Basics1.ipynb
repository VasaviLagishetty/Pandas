# %% [markdown]
# <a href="https://colab.research.google.com/github/VasaviLagishetty/Pandas/blob/master/DataFrame_Basics1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Reading CSV file

# %%
url = "https://raw.githubusercontent.com/VasaviLagishetty/Pandas/master/Datasets/jamesbond.csv"
jamesbond = pd.read_csv(url)
jamesbond.head(15)
# Out:
#                                Film  Year  ... Budget Bond Actor Salary
# 0                            Dr. No  1962  ...    7.0               0.6
# 1             From Russia with Love  1963  ...   12.6               1.6
# 2                        Goldfinger  1964  ...   18.6               3.2
# 3                       Thunderball  1965  ...   41.9               4.7
# 4                     Casino Royale  1967  ...   85.0               NaN
# 5               You Only Live Twice  1967  ...   59.9               4.4
# 6   On Her Majesty's Secret Service  1969  ...   37.3               0.6
# 7              Diamonds Are Forever  1971  ...   34.7               5.8
# 8                  Live and Let Die  1973  ...   30.8               NaN
# 9       The Man with the Golden Gun  1974  ...   27.7               NaN
# 10             The Spy Who Loved Me  1977  ...   45.1               NaN
# 11                        Moonraker  1979  ...   91.5               NaN
# ...

# %% [markdown]
# ## set_index( ) and reset_index( ) methods

# %%
jamesbond = jamesbond.set_index("Film")      # setting Film column as index
jamesbond.head(5)
# Out:
#                        Year         Actor  ... Budget  Bond Actor Salary
# Film                                       ...
# Dr. No                 1962  Sean Connery  ...    7.0                0.6
# From Russia with Love  1963  Sean Connery  ...   12.6                1.6
# Goldfinger             1964  Sean Connery  ...   18.6                3.2
# Thunderball            1965  Sean Connery  ...   41.9                4.7
# Casino Royale          1967   David Niven  ...   85.0                NaN
#
# [5 rows x 6 columns]

# %%
jamesbond = jamesbond.reset_index(drop=False)        # dropping film column as index
jamesbond.head(5)
# Out:
#                     Film  Year  ... Budget Bond Actor Salary
# 0                 Dr. No  1962  ...    7.0               0.6
# 1  From Russia with Love  1963  ...   12.6               1.6
# 2             Goldfinger  1964  ...   18.6               3.2
# 3            Thunderball  1965  ...   41.9               4.7
# 4          Casino Royale  1967  ...   85.0               NaN
#
# [5 rows x 7 columns]

# %%
jamesbond = jamesbond.set_index("Director")         # setting Director as index
jamesbond.head(5)
# Out:
#                                 Film  Year  ... Budget  Bond Actor Salary
# Director                                    ...
# Terence Young                 Dr. No  1962  ...    7.0                0.6
# Terence Young  From Russia with Love  1963  ...   12.6                1.6
# Guy Hamilton              Goldfinger  1964  ...   18.6                3.2
# Terence Young            Thunderball  1965  ...   41.9                4.7
# Ken Hughes             Casino Royale  1967  ...   85.0                NaN
#
# [5 rows x 6 columns]

# %%
jamesbond = jamesbond.reset_index(drop = False)
jamesbond = jamesbond.set_index("Year")            # setting Year as index
jamesbond.head(6)
# Out:
#            Director                   Film  ... Budget  Bond Actor Salary
# Year                                        ...
# 1962  Terence Young                 Dr. No  ...    7.0                0.6
# 1963  Terence Young  From Russia with Love  ...   12.6                1.6
# 1964   Guy Hamilton             Goldfinger  ...   18.6                3.2
# 1965  Terence Young            Thunderball  ...   41.9                4.7
# 1967     Ken Hughes          Casino Royale  ...   85.0                NaN
# 1967  Lewis Gilbert    You Only Live Twice  ...   59.9                4.4
#
# [6 rows x 6 columns]

# %% [markdown]
# ## loc( ) and iloc( ) methods

# %%
jamesbond.loc[2006]        # iloc['column_value'] used for retrieving complete row based on index column
# Out:
# Director             Martin Campbell
# Film                   Casino Royale
# Actor                   Daniel Craig
# Box Office                     581.5
# Budget                         145.3
# Bond Actor Salary                3.3
# Name: 2006, dtype: object

# %%
jamesbond.loc[1967]
# Out:
#            Director                 Film  ... Budget  Bond Actor Salary
# Year                                      ...
# 1967     Ken Hughes        Casino Royale  ...   85.0                NaN
# 1967  Lewis Gilbert  You Only Live Twice  ...   59.9                4.4
#
# [2 rows x 6 columns]

# %%
jamesbond = jamesbond.reset_index(drop = False)
jamesbond = jamesbond.set_index("Film")
jamesbond = jamesbond.sort_index(ascending=False)
jamesbond.head(5)
# Out:
#                          Year            Director  ... Budget  Bond Actor Salary
# Film                                               ...
# You Only Live Twice      1967       Lewis Gilbert  ...   59.9                4.4
# Tomorrow Never Dies      1997  Roger Spottiswoode  ...  133.9               10.0
# Thunderball              1965       Terence Young  ...   41.9                4.7
# The World Is Not Enough  1999       Michael Apted  ...  158.3               13.5
# The Spy Who Loved Me     1977       Lewis Gilbert  ...   45.1                NaN
#
# [5 rows x 6 columns]

# %%
jamesbond.loc['Dr. No']
# Out:
# Year                          1962
# Director             Terence Young
# Actor                 Sean Connery
# Box Office                   448.8
# Budget                           7
# Bond Actor Salary              0.6
# Name: Dr. No, dtype: object

# %%
jamesbond.loc["Tomorrow Never Dies":"Skyfall"]
# Out:
#                              Year  ... Bond Actor Salary
# Film                               ...
# Tomorrow Never Dies          1997  ...              10.0
# Thunderball                  1965  ...               4.7
# The World Is Not Enough      1999  ...              13.5
# The Spy Who Loved Me         1977  ...               NaN
# The Man with the Golden Gun  1974  ...               NaN
# The Living Daylights         1987  ...               5.2
# Spectre                      2015  ...               NaN
# Skyfall                      2012  ...              14.5
#
# [8 rows x 6 columns]

# %%
jamesbond.loc[["Spectre", "Quantum of Solace","The World Is Not Enough"]]
# Out:
#                          Year       Director  ... Budget  Bond Actor Salary
# Film                                          ...
# Spectre                  2015     Sam Mendes  ...  206.3                NaN
# Quantum of Solace        2008   Marc Forster  ...  181.4                8.1
# The World Is Not Enough  1999  Michael Apted  ...  158.3               13.5
#
# [3 rows x 6 columns]

# %%
"Die Another Day" in jamesbond.index
# Out:
# True

# %%
jamesbond = jamesbond.reset_index(drop=False)
jamesbond.head(10)
# Out:
#                           Film  Year  ... Budget Bond Actor Salary
# 0          You Only Live Twice  1967  ...   59.9               4.4
# 1          Tomorrow Never Dies  1997  ...  133.9              10.0
# 2                  Thunderball  1965  ...   41.9               4.7
# 3      The World Is Not Enough  1999  ...  158.3              13.5
# 4         The Spy Who Loved Me  1977  ...   45.1               NaN
# 5  The Man with the Golden Gun  1974  ...   27.7               NaN
# 6         The Living Daylights  1987  ...   68.8               5.2
# 7                      Spectre  2015  ...  206.3               NaN
# 8                      Skyfall  2012  ...  170.2              14.5
# 9            Quantum of Solace  2008  ...  181.4               8.1
#
# [10 rows x 7 columns]

# %%
jamesbond.loc[15]
# Out:
# Film                 Licence to Kill
# Year                            1989
# Director                   John Glen
# Actor                 Timothy Dalton
# Box Office                     250.9
# Budget                          56.7
# Bond Actor Salary                7.9
# Name: 15, dtype: object

# %%
jamesbond.iloc[15]         # iloc[] is used for integer index based on retrieving of rows
# Out:
# Film                 Licence to Kill
# Year                            1989
# Director                   John Glen
# Actor                 Timothy Dalton
# Box Office                     250.9
# Budget                          56.7
# Bond Actor Salary                7.9
# Name: 15, dtype: object

# %%
print(jamesbond.iloc[3:7])
print(jamesbond.iloc[[25,3]])
# Out:
#                           Film  Year  ... Budget Bond Actor Salary
# 3      The World Is Not Enough  1999  ...  158.3              13.5
# 4         The Spy Who Loved Me  1977  ...   45.1               NaN
# 5  The Man with the Golden Gun  1974  ...   27.7               NaN
# 6         The Living Daylights  1987  ...   68.8               5.2
#
# [4 rows x 7 columns]
#                        Film  Year  ... Budget Bond Actor Salary
# 25         A View to a Kill  1985  ...   54.5               9.1
# 3   The World Is Not Enough  1999  ...  158.3              13.5
#
# [2 rows x 7 columns]

# %%
jamesbond = jamesbond.set_index("Film")
jamesbond.head(5)
# Out:
#                          Year            Director  ... Budget  Bond Actor Salary
# Film                                               ...
# You Only Live Twice      1967       Lewis Gilbert  ...   59.9                4.4
# Tomorrow Never Dies      1997  Roger Spottiswoode  ...  133.9               10.0
# Thunderball              1965       Terence Young  ...   41.9                4.7
# The World Is Not Enough  1999       Michael Apted  ...  158.3               13.5
# The Spy Who Loved Me     1977       Lewis Gilbert  ...   45.1                NaN
#
# [5 rows x 6 columns]

# %%
jamesbond.iloc[[2,4,6,8,10]]
# Out:
#                                  Year       Director  ... Budget  Bond Actor Salary
# Film                                                  ...
# Thunderball                      1965  Terence Young  ...   41.9                4.7
# The Spy Who Loved Me             1977  Lewis Gilbert  ...   45.1                NaN
# The Living Daylights             1987      John Glen  ...   68.8                5.2
# Skyfall                          2012     Sam Mendes  ...  170.2               14.5
# On Her Majesty's Secret Service  1969  Peter R. Hunt  ...   37.3                0.6
#
# [5 rows x 6 columns]

# %%
jamesbond.head(5)
# Out:
#                          Year            Director  ... Budget  Bond Actor Salary
# Film                                               ...
# You Only Live Twice      1967       Lewis Gilbert  ...   59.9                4.4
# Tomorrow Never Dies      1997  Roger Spottiswoode  ...  133.9               10.0
# Thunderball              1965       Terence Young  ...   41.9                4.7
# The World Is Not Enough  1999       Michael Apted  ...  158.3               13.5
# The Spy Who Loved Me     1977       Lewis Gilbert  ...   45.1                NaN
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Renaming Column Names

# %%
jamesbond = jamesbond.rename(columns = {'Year':'Release_date','Budget':'Investment'})       # renaming columns
jamesbond.head(5)
# Out:
#                          Release_date  ... Bond Actor Salary
# Film                                   ...
# You Only Live Twice              1967  ...               4.4
# Tomorrow Never Dies              1997  ...              10.0
# Thunderball                      1965  ...               4.7
# The World Is Not Enough          1999  ...              13.5
# The Spy Who Loved Me             1977  ...               NaN
#
# [5 rows x 6 columns]

# %%
jamesbond = jamesbond.rename(index = {'Thunderball' : 'Thunderball1','The World Is Not Enough':'Enough Not Is World The'})       # renaming index values
jamesbond.head(4)
# Out:
#                          Release_date  ... Bond Actor Salary
# Film                                   ...
# You Only Live Twice              1967  ...               4.4
# Tomorrow Never Dies              1997  ...              10.0
# Thunderball1                     1965  ...               4.7
# Enough Not Is World The          1999  ...              13.5
#
# [4 rows x 6 columns]

# %%
jamesbond.columns = ["Release Year", "Actor", "Director", "Revenue", "Investment", "Salary"]       # another way for changing column names
jamesbond.head(1)
# Out:
#                      Release Year          Actor  ... Investment  Salary
# Film                                              ...
# You Only Live Twice          1967  Lewis Gilbert  ...       59.9     4.4
#
# [1 rows x 6 columns]

# %%
jamesbond.sample(n = 3, axis = "columns").head(5)          # any random 3 columns
# Out:
#                          Release Year  Investment               Actor
# Film
# You Only Live Twice              1967        59.9       Lewis Gilbert
# Tomorrow Never Dies              1997       133.9  Roger Spottiswoode
# Thunderball1                     1965        41.9       Terence Young
# Enough Not Is World The          1999       158.3       Michael Apted
# The Spy Who Loved Me             1977        45.1       Lewis Gilbert

# %% [markdown]
# ## nlargest() and nsmallest( ) methods

# %%
jamesbond.nlargest(3, columns = "Investment")
# Out:
#                    Release Year         Actor  ... Investment  Salary
# Film                                           ...
# Spectre                    2015    Sam Mendes  ...      206.3     NaN
# Quantum of Solace          2008  Marc Forster  ...      181.4     8.1
# Skyfall                    2012    Sam Mendes  ...      170.2    14.5
#
# [3 rows x 6 columns]

# %%
jamesbond.nsmallest(n = 2, columns = "Revenue")
# Out:
#                   Release Year      Actor  ... Investment  Salary
# Film                                       ...
# Licence to Kill           1989  John Glen  ...       56.7     7.9
# A View to a Kill          1985  John Glen  ...       54.5     9.1
#
# [2 rows x 6 columns]

# %%
jamesbond["Revenue"].nlargest(5)
# Out:
# Film
# Skyfall          943.5
# Thunderball1     848.1
# Goldfinger       820.4
# Spectre          726.7
# Casino Royale    581.5
# Name: Revenue, dtype: float64

# %%
jamesbond["Salary"].nsmallest(5)
# Out:
# Film
# On Her Majesty's Secret Service    0.6
# Dr. No                             0.6
# From Russia with Love              1.6
# Goldfinger                         3.2
# Casino Royale                      3.3
# Name: Salary, dtype: float64

# %% [markdown]
# ## where( ) method

# %%
part1 = jamesbond["Director"] == "Daniel Craig"
jamesbond[part1]
# Out:
#                    Release Year            Actor  ... Investment  Salary
# Film                                              ...
# Spectre                    2015       Sam Mendes  ...      206.3     NaN
# Skyfall                    2012       Sam Mendes  ...      170.2    14.5
# Quantum of Solace          2008     Marc Forster  ...      181.4     8.1
# Casino Royale              2006  Martin Campbell  ...      145.3     3.3
#
# [4 rows x 6 columns]

# %%
jamesbond.where(part1)
# Out:
#                                  Release Year  ... Salary
# Film                                           ...
# You Only Live Twice                       NaN  ...    NaN
# Tomorrow Never Dies                       NaN  ...    NaN
# Thunderball1                              NaN  ...    NaN
# Enough Not Is World The                   NaN  ...    NaN
# The Spy Who Loved Me                      NaN  ...    NaN
# The Man with the Golden Gun               NaN  ...    NaN
# The Living Daylights                      NaN  ...    NaN
# Spectre                                2015.0  ...    NaN
# Skyfall                                2012.0  ...   14.5
# Quantum of Solace                      2008.0  ...    8.1
# On Her Majesty's Secret Service           NaN  ...    NaN
# Octopussy                                 NaN  ...    NaN
# Never Say Never Again                     NaN  ...    NaN
# Moonraker                                 NaN  ...    NaN
# ...

# %%
part2 = jamesbond["Salary"]>8.0

# %%
jamesbond.where(jamesbond["Revenue"] > 500.0)
# Out:
#                                  Release Year  ... Salary
# Film                                           ...
# You Only Live Twice                    1967.0  ...    4.4
# Tomorrow Never Dies                       NaN  ...    NaN
# Thunderball1                           1965.0  ...    4.7
# Enough Not Is World The                   NaN  ...    NaN
# The Spy Who Loved Me                   1977.0  ...    NaN
# The Man with the Golden Gun               NaN  ...    NaN
# The Living Daylights                      NaN  ...    NaN
# Spectre                                2015.0  ...    NaN
# Skyfall                                2012.0  ...   14.5
# Quantum of Solace                      2008.0  ...    8.1
# On Her Majesty's Secret Service           NaN  ...    NaN
# Octopussy                                 NaN  ...    NaN
# Never Say Never Again                     NaN  ...    NaN
# Moonraker                              1979.0  ...    NaN
# ...

# %%
jamesbond.where(part1 & part2)
# Out:
#                                  Release Year         Actor  ... Investment  Salary
# Film                                                         ...
# You Only Live Twice                       NaN           NaN  ...        NaN     NaN
# Tomorrow Never Dies                       NaN           NaN  ...        NaN     NaN
# Thunderball1                              NaN           NaN  ...        NaN     NaN
# Enough Not Is World The                   NaN           NaN  ...        NaN     NaN
# The Spy Who Loved Me                      NaN           NaN  ...        NaN     NaN
# The Man with the Golden Gun               NaN           NaN  ...        NaN     NaN
# The Living Daylights                      NaN           NaN  ...        NaN     NaN
# Spectre                                   NaN           NaN  ...        NaN     NaN
# Skyfall                                2012.0    Sam Mendes  ...      170.2    14.5
# ...

# %%
jamesbond.where(part1 | part2)
# Out:
#                                  Release Year  ... Salary
# Film                                           ...
# You Only Live Twice                       NaN  ...    NaN
# Tomorrow Never Dies                    1997.0  ...   10.0
# Thunderball1                              NaN  ...    NaN
# Enough Not Is World The                1999.0  ...   13.5
# The Spy Who Loved Me                      NaN  ...    NaN
# The Man with the Golden Gun               NaN  ...    NaN
# The Living Daylights                      NaN  ...    NaN
# Spectre                                2015.0  ...    NaN
# Skyfall                                2012.0  ...   14.5
# Quantum of Solace                      2008.0  ...    8.1
# On Her Majesty's Secret Service           NaN  ...    NaN
# Octopussy                                 NaN  ...    NaN
# Never Say Never Again                     NaN  ...    NaN
# Moonraker                                 NaN  ...    NaN
# ...

# %%
jamesbond.columns = [column_name.replace(" ", "_") for column_name in jamesbond.columns]
jamesbond.head(1)
# Out:
#                      Release_Year          Actor  ... Investment  Salary
# Film                                              ...
# You Only Live Twice          1967  Lewis Gilbert  ...       59.9     4.4
#
# [1 rows x 6 columns]

# %% [markdown]
# ## query( ) method

# %%
jamesbond.query('Actor == "John Glen"')
# Out:
#                       Release_Year      Actor  ... Investment  Salary
# Film                                           ...
# The Living Daylights          1987  John Glen  ...       68.8     5.2
# Octopussy                     1983  John Glen  ...       53.9     7.8
# Licence to Kill               1989  John Glen  ...       56.7     7.9
# For Your Eyes Only            1981  John Glen  ...       60.2     NaN
# A View to a Kill              1985  John Glen  ...       54.5     9.1
#
# [5 rows x 6 columns]

# %%
jamesbond.query('Director != "Timothy Dalton"')
# Out:
#                                  Release_Year  ... Salary
# Film                                           ...
# You Only Live Twice                      1967  ...    4.4
# Tomorrow Never Dies                      1997  ...   10.0
# Thunderball1                             1965  ...    4.7
# Enough Not Is World The                  1999  ...   13.5
# The Spy Who Loved Me                     1977  ...    NaN
# The Man with the Golden Gun              1974  ...    NaN
# Spectre                                  2015  ...    NaN
# Skyfall                                  2012  ...   14.5
# Quantum of Solace                        2008  ...    8.1
# On Her Majesty's Secret Service          1969  ...    0.6
# Octopussy                                1983  ...    7.8
# Never Say Never Again                    1983  ...    NaN
# Moonraker                                1979  ...    NaN
# Live and Let Die                         1973  ...    NaN
# ...

# %%
jamesbond.query("Revenue > 700.0 and Investment > 130.0")
# Out:
#          Release_Year       Actor      Director  Revenue  Investment  Salary
# Film
# Spectre          2015  Sam Mendes  Daniel Craig    726.7       206.3     NaN
# Skyfall          2012  Sam Mendes  Daniel Craig    943.5       170.2    14.5

# %%
jamesbond.query("Director in ['Pierce Brosnan', 'Roger Moore']")
# Out:
#                              Release_Year  ... Salary
# Film                                       ...
# Tomorrow Never Dies                  1997  ...   10.0
# Enough Not Is World The              1999  ...   13.5
# The Spy Who Loved Me                 1977  ...    NaN
# The Man with the Golden Gun          1974  ...    NaN
# Octopussy                            1983  ...    7.8
# Moonraker                            1979  ...    NaN
# Live and Let Die                     1973  ...    NaN
# GoldenEye                            1995  ...    5.1
# For Your Eyes Only                   1981  ...    NaN
# Die Another Day                      2002  ...   17.9
# A View to a Kill                     1985  ...    9.1
#
# [11 rows x 6 columns]

# %%
jamesbond.query("Actor not in ['John Glen','Guy Hamilton']")
# Out:
#                                  Release_Year  ... Salary
# Film                                           ...
# You Only Live Twice                      1967  ...    4.4
# Tomorrow Never Dies                      1997  ...   10.0
# Thunderball1                             1965  ...    4.7
# Enough Not Is World The                  1999  ...   13.5
# The Spy Who Loved Me                     1977  ...    NaN
# Spectre                                  2015  ...    NaN
# Skyfall                                  2012  ...   14.5
# Quantum of Solace                        2008  ...    8.1
# On Her Majesty's Secret Service          1969  ...    0.6
# Never Say Never Again                    1983  ...    NaN
# Moonraker                                1979  ...    NaN
# GoldenEye                                1995  ...    5.1
# From Russia with Love                    1963  ...    1.6
# Dr. No                                   1962  ...    0.6
# ...

# %% [markdown]
# ## apply( ) method

# %%
def divide_by_ten(n):
  return round(n/10,2)

# %%
def adding_millons_to_number(n):
  return str(n)+' Millions'

# %%
for columns in ['Revenue','Investment','Salary']:
  jamesbond[columns] = jamesbond[columns].apply(divide_by_ten)
  jamesbond[columns] = jamesbond[columns].apply(adding_millons_to_number)
jamesbond.head(5)
# Out:
#                          Release_Year  ...         Salary
# Film                                   ...
# You Only Live Twice              1967  ...  0.44 Millions
# Tomorrow Never Dies              1997  ...   1.0 Millions
# Thunderball1                     1965  ...  0.47 Millions
# Enough Not Is World The          1999  ...  1.35 Millions
# The Spy Who Loved Me             1977  ...   nan Millions
#
# [5 rows x 6 columns]

# %%
def object_type_to_float(n):
  return float(n[:-8])*10

for columns in ['Revenue','Investment','Salary']:
  jamesbond[columns] = jamesbond[columns].apply(object_type_to_float)
jamesbond.head(5)
# Out:
#                          Release_Year               Actor  ... Investment  Salary
# Film                                                       ...
# You Only Live Twice              1967       Lewis Gilbert  ...       59.9     4.4
# Tomorrow Never Dies              1997  Roger Spottiswoode  ...      133.9    10.0
# Thunderball1                     1965       Terence Young  ...       41.9     4.7
# Enough Not Is World The          1999       Michael Apted  ...      158.3    13.5
# The Spy Who Loved Me             1977       Lewis Gilbert  ...       45.1     NaN
#
# [5 rows x 6 columns]

# %%
jamesbond.dtypes
# Out:
# Release_Year      int64
# Actor            object
# Director         object
# Revenue         float64
# Investment      float64
# Salary          float64
# dtype: object

# %%
def good_better_best_movie(row):
  director = row[2]
  revenue = row[3]
  if director == 'Pierce Brosnan':
    return "Best"
  elif director == "Daniel Craig" and revenue > 600.0:
    return "Comedy"
  else:
    return "No idea..!"

jamesbond.apply(good_better_best_movie,axis = 'columns')
# Out:
# Film
# You Only Live Twice                No idea..!
# Tomorrow Never Dies                      Best
# Thunderball1                       No idea..!
# Enough Not Is World The                  Best
# The Spy Who Loved Me               No idea..!
# The Man with the Golden Gun        No idea..!
# The Living Daylights               No idea..!
# Spectre                                Comedy
# Skyfall                                Comedy
# Quantum of Solace                  No idea..!
# On Her Majesty's Secret Service    No idea..!
# Octopussy                          No idea..!
# Never Say Never Again              No idea..!
# Moonraker                          No idea..!
# Live and Let Die                   No idea..!
# Licence to Kill                    No idea..!
# Goldfinger                         No idea..!
# GoldenEye                                Best
# From Russia with Love              No idea..!
# For Your Eyes Only                 No idea..!
# ...

# %% [markdown]
# ## copy( ) method

# %%
jamesbond.head(3)
# Out:
#                      Release_Year               Actor  ... Investment  Salary
# Film                                                   ...
# You Only Live Twice          1967       Lewis Gilbert  ...       59.9     4.4
# Tomorrow Never Dies          1997  Roger Spottiswoode  ...      133.9    10.0
# Thunderball1                 1965       Terence Young  ...       41.9     4.7
#
# [3 rows x 6 columns]

# %%
Release_date = jamesbond['Release_Year']
Release_date.head(5)
# Out:
# Film
# You Only Live Twice        1967
# Tomorrow Never Dies        1997
# Thunderball1               1965
# Enough Not Is World The    1999
# The Spy Who Loved Me       1977
# Name: Release_Year, dtype: int64

# %%
Release_date['Enough Not Is World The'] = 1998
Release_date.head(5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Film
# You Only Live Twice        1967
# Tomorrow Never Dies        1997
# Thunderball1               1965
# Enough Not Is World The    1998
# The Spy Who Loved Me       1977
# Name: Release_Year, dtype: int64

# %%
print(jamesbond.loc["Enough Not Is World The"])
jamesbond.head(5)
# Out:
# Release_Year              1998
# Actor            Michael Apted
# Director        Pierce Brosnan
# Revenue                  439.5
# Investment               158.3
# Salary                    13.5
# Name: Enough Not Is World The, dtype: object
#                          Release_Year               Actor  ... Investment  Salary
# Film                                                       ...
# You Only Live Twice              1967       Lewis Gilbert  ...       59.9     4.4
# Tomorrow Never Dies              1997  Roger Spottiswoode  ...      133.9    10.0
# Thunderball1                     1965       Terence Young  ...       41.9     4.7
# Enough Not Is World The          1998       Michael Apted  ...      158.3    13.5
# The Spy Who Loved Me             1977       Lewis Gilbert  ...       45.1     NaN
#
# [5 rows x 6 columns]

# %%
Release_date_copy = jamesbond["Release_Year"].copy()

# %%
Release_date_copy["Enough Not Is World The"] = 1999
Release_date_copy.head(5)
# Out:
# Film
# You Only Live Twice        1967
# Tomorrow Never Dies        1997
# Thunderball1               1965
# Enough Not Is World The    1999
# The Spy Who Loved Me       1977
# Name: Release_Year, dtype: int64

# %%
print(jamesbond.loc["Enough Not Is World The"])
jamesbond.head(5)
# Out:
# Release_Year              1998
# Actor            Michael Apted
# Director        Pierce Brosnan
# Revenue                  439.5
# Investment               158.3
# Salary                    13.5
# Name: Enough Not Is World The, dtype: object
#                          Release_Year               Actor  ... Investment  Salary
# Film                                                       ...
# You Only Live Twice              1967       Lewis Gilbert  ...       59.9     4.4
# Tomorrow Never Dies              1997  Roger Spottiswoode  ...      133.9    10.0
# Thunderball1                     1965       Terence Young  ...       41.9     4.7
# Enough Not Is World The          1998       Michael Apted  ...      158.3    13.5
# The Spy Who Loved Me             1977       Lewis Gilbert  ...       45.1     NaN
#
# [5 rows x 6 columns]
